# %% [markdown]
# <a href="https://colab.research.google.com/github/Mak-Wei-Zheng/stgat_thesis/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !nvidia-smi
# Out:
# Tue Apr 23 16:26:47 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P0              28W /  70W |    349MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
# This get the RAPIDS-Colab install files and test check your GPU.  Run this and the next cell only.
# Please read the output of this cell.  If your Colab Instance is not RAPIDS compatible, it will warn you and give you remediation steps.
# !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
# !python rapidsai-csp-utils/colab/pip-install.py
# Out:
# fatal: destination path 'rapidsai-csp-utils' already exists and is not an empty directory.
# Traceback (most recent call last):
#   File "/content/rapidsai-csp-utils/colab/pip-install.py", line 30, in <module>
#     if ('P' not in gpu_name):
# TypeError: a bytes-like object is required, not 'str'

# %%
# prompt: import libraries for linear regression using cuml
import numpy as np
import cupy as cp

import pandas as pd
import cudf as cd

import numba
import numba.cuda

from cuml import Ridge as cumlRidge

from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
raw_data = pd.read_csv("/content/drive/MyDrive/raw_all_data.csv")

# %%
raw_data.shape
# Out:
# (162575, 24)

# %%
raw_data.dtypes
# Out:
# Date                                               object
# SORA Index                                        float64
# Compound SORA - 1 month                           float64
# Compound SORA - 3 month                           float64
# Quarterly Composite Leading Index                 float64
# Services Inflation Measure (Index)                float64
# Retail & Other Goods Inflation Measure (Index)    float64
# Electricity & Gas Inflation Measure (Index)       float64
# Week                                              float64
# Year                                              float64
# Transacted Price ($)                              float64
# Area (SQFT)                                       float64
# Type of Sale                                       object
# Type of Area                                       object
# Property Type                                      object
# Postal District                                   float64
# Planning Region                                    object
# Planning Area                                      object
# Sale Date                                          object
# latitude                                          float64
# longitude                                         float64
# is_freehold                                        object
# tenure_remaining                                  float64
# region classification                              object
# dtype: object

# %%
raw_data["Transacted Price ($)"].head()
# Out:
# 0    2160605.75
# 1    1186731.00
# 2    1979959.12
# 3    2820688.12
# 4    1299973.08
# Name: Transacted Price ($), dtype: float64

# %% [markdown]
# ### This portion of the code is for grid search over LR variables with my custom train-val-test split

# %%
# trim data
columns_to_drop = ["SORA Index", "Compound SORA - 1 month", "Sale Date"]
lr_total_df = raw_data.drop(columns_to_drop, axis=1)
lr_total_df.head()
# Out:
#          Date  Compound SORA - 3 month  Quarterly Composite Leading Index  \
# 0  2014-02-28                   0.0444                               99.8
# 1  2014-02-28                   0.0444                               99.8
# 2  2014-02-28                   0.0444                               99.8
# 3  2014-02-28                   0.0444                               99.8
# 4  2014-02-28                   0.0444                               99.8
#
#    Services Inflation Measure (Index)  \
# 0                              93.063
# 1                              93.063
# 2                              93.063
# 3                              93.063
# 4                              93.063
#
#    Retail & Other Goods Inflation Measure (Index)  \
# 0                                          97.714
# 1                                          97.714
# 2                                          97.714
# 3                                          97.714
# 4                                          97.714
#
#    Electricity & Gas Inflation Measure (Index)  Week    Year  \
# 0                                      117.098   9.0  2014.0
# 1                                      117.098   9.0  2014.0
# 2                                      117.098   9.0  2014.0
# 3                                      117.098   9.0  2014.0
# 4                                      117.098   9.0  2014.0
#
#    Transacted Price ($)  Area (SQFT)  ... Type of Area Property Type  \
# 0            2160605.75      2335.79  ...       Strata   Condominium
# 1            1186731.00       968.76  ...       Strata   Condominium
# 2            1979959.12      1065.64  ...       Strata   Condominium
# 3            2820688.12      1636.13  ...       Strata   Condominium
# 4            1299973.08       871.88  ...       Strata   Condominium
#
#   Postal District    Planning Region Planning Area   latitude   longitude  \
# 0            11.0     Central Region   Bukit Timah  35.417740  -78.461267
# 1            13.0     Central Region     Toa Payoh  55.915648   -3.156864
# 2            10.0     Central Region       Tanglin  52.906050   -1.375444
# 3             4.0     Central Region   Bukit Merah   1.265778  103.814563
# 4            20.0  North East Region    Ang Mo Kio   1.370357  103.848536
#
#    is_freehold tenure_remaining  region classification
# 0         True              NaN                    CCR
# 1        False          35452.0                    RCR
# 2         True              NaN                    CCR
# 3        False          30825.0                    RCR
# 4        False          33864.0                    OCR
#
# [5 rows x 21 columns]

# %%
# categorical encoding
one_hot_cols = ["region classification", "Type of Area", "Type of Sale"]
binary_cols = ["Planning Area", "Postal District", "Property Type", "Planning Region"]

# %%
# !pip install category-encoders
# Out:
# Requirement already satisfied: category-encoders in /usr/local/lib/python3.10/dist-packages (2.6.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (1.11.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (0.14.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (2.0.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category-encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category-encoders) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category-encoders) (2024.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category-encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category-encoders) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category-encoders) (3.4.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category-encoders) (24.0)

# %%
import category_encoders as ce

# Create a binary encoder
encoder = ce.BinaryEncoder(cols=binary_cols)

# Fit and transform to generate binary encoded DataFrame
binary_encoded_df = encoder.fit_transform(lr_total_df)

# one-hot encode
total_encoded_df = pd.get_dummies(binary_encoded_df, columns=one_hot_cols, prefix='cat')

# %%
total_encoded_df.dtypes
# Out:
# Date                                               object
# Compound SORA - 3 month                           float64
# Quarterly Composite Leading Index                 float64
# Services Inflation Measure (Index)                float64
# Retail & Other Goods Inflation Measure (Index)    float64
# Electricity & Gas Inflation Measure (Index)       float64
# Week                                              float64
# Year                                              float64
# Transacted Price ($)                              float64
# Area (SQFT)                                       float64
# Property Type_0                                     int64
# Property Type_1                                     int64
# Property Type_2                                     int64
# Postal District_0                                   int64
# Postal District_1                                   int64
# Postal District_2                                   int64
# Postal District_3                                   int64
# Postal District_4                                   int64
# Planning Region_0                                   int64
# Planning Region_1                                   int64
# Planning Region_2                                   int64
# Planning Area_0                                     int64
# Planning Area_1                                     int64
# Planning Area_2                                     int64
# Planning Area_3                                     int64
# Planning Area_4                                     int64
# Planning Area_5                                     int64
# latitude                                          float64
# longitude                                         float64
# is_freehold                                        object
# tenure_remaining                                  float64
# cat_CCR                                              bool
# cat_OCR                                              bool
# cat_RCR                                              bool
# cat_Land                                             bool
# cat_Strata                                           bool
# cat_New Sale                                         bool
# cat_Resale                                           bool
# cat_Sub Sale                                         bool
# dtype: object

# %%
# convert date to datetime object
from datetime import datetime

total_encoded_df["Date"] = total_encoded_df["Date"].apply(lambda x: datetime.strptime(x, "%Y-%m-%d"))

# %%
total_encoded_df["Transacted Price ($)"] = lr_total_df["Transacted Price ($)"]

# %%
total_encoded_df["tenure_remaining"].fillna(0, inplace=True)
total_encoded_df.dropna(axis=0, inplace=True)
total_encoded_df.head()
# Out:
#         Date  Compound SORA - 3 month  Quarterly Composite Leading Index  \
# 0 2014-02-28                   0.0444                               99.8
# 1 2014-02-28                   0.0444                               99.8
# 2 2014-02-28                   0.0444                               99.8
# 3 2014-02-28                   0.0444                               99.8
# 4 2014-02-28                   0.0444                               99.8
#
#    Services Inflation Measure (Index)  \
# 0                              93.063
# 1                              93.063
# 2                              93.063
# 3                              93.063
# 4                              93.063
#
#    Retail & Other Goods Inflation Measure (Index)  \
# 0                                          97.714
# 1                                          97.714
# 2                                          97.714
# 3                                          97.714
# 4                                          97.714
#
#    Electricity & Gas Inflation Measure (Index)  Week    Year  \
# 0                                      117.098   9.0  2014.0
# 1                                      117.098   9.0  2014.0
# 2                                      117.098   9.0  2014.0
# 3                                      117.098   9.0  2014.0
# 4                                      117.098   9.0  2014.0
#
#    Transacted Price ($)  Area (SQFT)  ...  is_freehold  tenure_remaining  \
# 0            2160605.75      2335.79  ...         True               0.0
# 1            1186731.00       968.76  ...        False           35452.0
# 2            1979959.12      1065.64  ...         True               0.0
# 3            2820688.12      1636.13  ...        False           30825.0
# 4            1299973.08       871.88  ...        False           33864.0
#
#    cat_CCR  cat_OCR  cat_RCR  cat_Land  cat_Strata  cat_New Sale  cat_Resale  \
# 0     True    False    False     False        True         False        True
# 1    False    False     True     False        True          True       False
# 2     True    False    False     False        True         False        True
# 3    False    False     True     False        True         False        True
# 4    False     True    False     False        True         False       False
#
#    cat_Sub Sale
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#
# [5 rows x 39 columns]

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.2

# %%
encoded_cudf = cd.from_pandas(total_encoded_df)

# %%
encoded_cudf.head()
# Out:
#         Date  Compound SORA - 3 month  Quarterly Composite Leading Index  \
# 0 2014-02-28                   0.0444                               99.8
# 1 2014-02-28                   0.0444                               99.8
# 2 2014-02-28                   0.0444                               99.8
# 3 2014-02-28                   0.0444                               99.8
# 4 2014-02-28                   0.0444                               99.8
#
#    Services Inflation Measure (Index)  \
# 0                              93.063
# 1                              93.063
# 2                              93.063
# 3                              93.063
# 4                              93.063
#
#    Retail & Other Goods Inflation Measure (Index)  \
# 0                                          97.714
# 1                                          97.714
# 2                                          97.714
# 3                                          97.714
# 4                                          97.714
#
#    Electricity & Gas Inflation Measure (Index)  Week    Year  \
# 0                                      117.098   9.0  2014.0
# 1                                      117.098   9.0  2014.0
# 2                                      117.098   9.0  2014.0
# 3                                      117.098   9.0  2014.0
# 4                                      117.098   9.0  2014.0
#
#    Transacted Price ($)  Area (SQFT)  ...  is_freehold  tenure_remaining  \
# 0            2160605.75      2335.79  ...         True               0.0
# 1            1186731.00       968.76  ...        False           35452.0
# 2            1979959.12      1065.64  ...         True               0.0
# 3            2820688.12      1636.13  ...        False           30825.0
# 4            1299973.08       871.88  ...        False           33864.0
#
#    cat_CCR  cat_OCR  cat_RCR  cat_Land  cat_Strata  cat_New Sale  cat_Resale  \
# 0     True    False    False     False        True         False        True
# 1    False    False     True     False        True          True       False
# 2     True    False    False     False        True         False        True
# 3    False    False     True     False        True         False        True
# 4    False     True    False     False        True         False       False
#
#    cat_Sub Sale
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#
# [5 rows x 39 columns]

# %%
# convert week and year to int
encoded_cudf["Year"] = encoded_cudf["Year"].astype(int)
encoded_cudf["Week"] = encoded_cudf["Week"].astype(int)

# %%
def filter_years(df, start_year, end_year=None):
    if end_year is None:
        end_year = start_year
    return df[(df['Year'] >= start_year) & (df['Year'] <= end_year)]

def get_latest_year_indices(df):
    max_year = df['Year'].max()
    return df[df['Year'] == max_year].index

search_set = filter_years(encoded_cudf, 2014, 2022) # representing ~9 years of data

final_train_set = filter_years(encoded_cudf, 2019, 2022)
final_test_set = filter_years(encoded_cudf, 2023)

print(search_set.shape, final_train_set.shape, final_test_set.shape)
# Out:
# (146243, 39) (76887, 39) (16229, 39)

# %%
# import dependencies
from cuml.linear_model import LinearRegression
from cuml.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.pipeline import Pipeline
import numpy as np

# %%
pipeline = Pipeline([
    ("scaler", MinMaxScaler()),
    ("regressor", LinearRegression())
])
# Out:
# /usr/local/lib/python3.10/dist-packages/cuml/internals/api_decorators.py:382: UserWarning: Starting from version 23.08, the new 'copy_X' parameter defaults to 'True', ensuring a copy of X is created after passing it to fit(), preventing any changes to the input, but with increased memory usage. This represents a change in behavior from previous versions. With `copy_X=False` a copy might still be created if necessary. Explicitly set 'copy_X' to either True or False to suppress this warning.
#   return init_func(self, *args, **filtered_kwargs)

# %%
param_grid = {
    # 'regressor__alpha': [100, 10, 1.0, 0.1, 0.01],
    'regressor__fit_intercept': [True, False],
    'regressor__normalize': [True, False]
}

# %%
# going for a 80-20 training split
tscv = TimeSeriesSplit(n_splits=9, max_train_size=4)

# %%
grid_search = GridSearchCV(pipeline, param_grid, cv=tscv, verbose=2)

# %%
features_to_drop = ["Transacted Price ($)", "Date"]
features_to_keep = [feature for feature in encoded_cudf.columns if feature not in features_to_drop]

# %%
# prepare data
lr_variables = search_set.drop(features_to_drop, axis=1).values
lr_target = search_set["Transacted Price ($)"].values

# %%
# Fit grid search (make sure to pass all columns except 'year' if it's not a feature)
grid_search.fit(lr_variables, lr_target)
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
# Out:
# Fitting 9 folds for each of 4 candidates, totalling 36 fits
# /usr/local/lib/python3.10/dist-packages/cupy/cuda/compiler.py:233: PerformanceWarning: Jitify is performing a one-time only warm-up to populate the persistent cache, this may take a few seconds and will be improved in a future release...
#   jitify._init_module()
# [CV] END regressor__fit_intercept=True, regressor__normalize=True; total time=  55.4s
# [CV] END regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# Best parameters: {'regressor__fit_intercept': True, 'regressor__normalize': False}
# Best score: -174.66860444054365

# %%
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
# Out:
# Best parameters: {'regressor__fit_intercept': True, 'regressor__normalize': False}
# Best score: -174.66860444054365

# %%
results_df = pd.DataFrame(grid_search.cv_results_)
results_df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       5.980374     16.885625         0.188828        0.518847
# 1       0.009834      0.000589         0.005608        0.000278
# 2       0.010579      0.001489         0.007490        0.004697
# 3       0.010585      0.001788         0.005871        0.000704
#
#   param_regressor__fit_intercept param_regressor__normalize  \
# 0                           True                       True
# 1                           True                      False
# 2                          False                       True
# 3                          False                      False
#
#                                               params  split0_test_score  \
# 0  {'regressor__fit_intercept': True, 'regressor_...          -3.376984
# 1  {'regressor__fit_intercept': True, 'regressor_...          -2.264967
# 2  {'regressor__fit_intercept': False, 'regressor...         -19.992186
# 3  {'regressor__fit_intercept': False, 'regressor...         -19.992186
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0       -3367.488014           0.659963           0.535645          -0.260810
# 1       -1221.269177           0.672615           0.544861          -0.220539
# 2         -68.195615           0.633908           0.560842          -0.207685
# 3         -68.195615           0.633908           0.560842          -0.207685
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0        -484.599128        -136.113763         -18.103744          -1.572523
# 1        -267.306759         -67.345816         -13.264519          -1.563139
# 2       -3608.201688        -914.121403        -139.183290          -1.869565
# 3       -3608.201688        -914.121403        -139.183290          -1.869565
#
#    mean_test_score  std_test_score  rank_test_score
# 0      -445.591040     1043.856037                2
# 1      -174.668604      379.046903                1
# 2      -527.841854     1124.060632                3
# 3      -527.841854     1124.060632                3

# %%
final_model = pipeline.set_params(**grid_search.best_params_)

# %%
# prepare data
train_variables = final_train_set.drop(features_to_drop, axis=1).values
train_target = final_train_set["Transacted Price ($)"].values

# %%
final_model.fit(train_variables,train_target)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('regressor', LinearRegression())])

# %%
X_test = final_test_set.drop(features_to_drop, axis=1).values
y_test = final_test_set["Transacted Price ($)"].values

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# Assume X_test and y_test are your test features and target variable
# Make predictions
y_pred = pipeline.predict(X_test)
print(y_pred)
print(y_test)

# Evaluate the model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

rmse = np.sqrt(mean_squared_error(y_test.get(), y_pred.get()))
mae = mean_absolute_error(y_test.get(), y_pred.get())
mape = mean_absolute_percentage_error(y_test.get(), y_pred.get())
r2 = r2_score(y_test.get(), y_pred.get())

# Print the performance metrics
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")
print(f"MAPE: {mape}")
print(f"R^2 Score: {r2}")
# Out:
# [1649344.86408709 1906479.44756301  991121.18546833 ... 2475427.04288905
#  2063187.42993116 2420241.02764117]
# [1338630.03  1823554.9   1060213.68  ... 2190680.8   1994234.588
#  2691080.43 ]
# Root Mean Squared Error: 1012982.0526714184
# Mean Absolute Error: 495141.7616994858
# MAPE: 23.289058219314615
# R^2 Score: 0.7833352090746664

# %%
from cuml.linear_model import Ridge

# %%
pipeline = Pipeline([
    ("scaler", MinMaxScaler()),
    ("regressor", Ridge())
])

# %%
param_grid = {
    'regressor__alpha': [100, 10, 1.0, 0.1, 0.01],
    'regressor__fit_intercept': [True, False],
    'regressor__normalize': [True, False]
}

# %%
# going for a 80-20 training split
tscv = TimeSeriesSplit(n_splits=9, max_train_size=4)

# %%
grid_search = GridSearchCV(pipeline, param_grid, cv=tscv, verbose=2)

# %%
features_to_drop = ["Transacted Price ($)", "Date"]
features_to_keep = [feature for feature in encoded_cudf.columns if feature not in features_to_drop]

# %%
# prepare data
lr_variables = search_set.drop(features_to_drop, axis=1).values
lr_target = search_set["Transacted Price ($)"].values

# %%
# Fit grid search (make sure to pass all columns except 'year' if it's not a feature)
grid_search.fit(lr_variables, lr_target)
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# %%
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
# Out:
# Best parameters: {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__normalize': False}
# Best score: -0.8112051395817362

# %%
results_df = pd.DataFrame(grid_search.cv_results_)
results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.011405      0.001413         0.005649        0.000829
# 1        0.011200      0.001902         0.005076        0.000125
# 2        0.010883      0.001408         0.004899        0.000133
# 3        0.011199      0.001676         0.004988        0.000138
# 4        0.011037      0.001504         0.004902        0.000102
# 5        0.011660      0.002236         0.005282        0.000312
# 6        0.011716      0.001494         0.005363        0.000224
# 7        0.011316      0.001420         0.005189        0.000082
# 8        0.011603      0.001534         0.005245        0.000183
# 9        0.011976      0.001927         0.005579        0.000306
# 10       0.011912      0.001723         0.005684        0.000912
# 11       0.011229      0.001950         0.005145        0.000155
# 12       0.011397      0.001011         0.005244        0.000256
# 13       0.012402      0.002334         0.005779        0.000290
# 14       0.011075      0.001463         0.005300        0.000263
# 15       0.011295      0.001965         0.005142        0.000172
# 16       0.010834      0.001155         0.005191        0.000183
# 17       0.012188      0.002116         0.005453        0.000172
# 18       0.011076      0.001430         0.005388        0.000152
# 19       0.011531      0.001757         0.005340        0.000185
#
#    param_regressor__alpha param_regressor__fit_intercept  \
# 0                     100                           True
# 1                     100                           True
# 2                     100                          False
# 3                     100                          False
# 4                      10                           True
# 5                      10                           True
# 6                      10                          False
# 7                      10                          False
# 8                     1.0                           True
# 9                     1.0                           True
# 10                    1.0                          False
# 11                    1.0                          False
# 12                    0.1                           True
# 13                    0.1                           True
# 14                    0.1                          False
# 15                    0.1                          False
# 16                   0.01                           True
# 17                   0.01                           True
# 18                   0.01                          False
# 19                   0.01                          False
#
#    param_regressor__normalize  \
# 0                        True
# 1                       False
# 2                        True
# 3                       False
# 4                        True
# 5                       False
# 6                        True
# 7                       False
# 8                        True
# 9                       False
# 10                       True
# 11                      False
# 12                       True
# 13                      False
# 14                       True
# 15                      False
# 16                       True
# 17                      False
# 18                       True
# 19                      False
#
#                                                params  split0_test_score  \
# 0   {'regressor__alpha': 100, 'regressor__fit_inte...          -0.694083
# 1   {'regressor__alpha': 100, 'regressor__fit_inte...          -0.061458
# 2   {'regressor__alpha': 100, 'regressor__fit_inte...          -0.737739
# 3   {'regressor__alpha': 100, 'regressor__fit_inte...          -0.737739
# 4   {'regressor__alpha': 10, 'regressor__fit_inter...          -4.369081
# 5   {'regressor__alpha': 10, 'regressor__fit_inter...          -1.291051
# 6   {'regressor__alpha': 10, 'regressor__fit_inter...         -14.548340
# 7   {'regressor__alpha': 10, 'regressor__fit_inter...         -14.548340
# 8   {'regressor__alpha': 1.0, 'regressor__fit_inte...          -3.937781
# 9   {'regressor__alpha': 1.0, 'regressor__fit_inte...          -3.294565
# 10  {'regressor__alpha': 1.0, 'regressor__fit_inte...         -25.497901
# 11  {'regressor__alpha': 1.0, 'regressor__fit_inte...         -25.497901
# 12  {'regressor__alpha': 0.1, 'regressor__fit_inte...          -3.444566
# 13  {'regressor__alpha': 0.1, 'regressor__fit_inte...          -2.487123
# 14  {'regressor__alpha': 0.1, 'regressor__fit_inte...         -21.125900
# 15  {'regressor__alpha': 0.1, 'regressor__fit_inte...         -21.125900
# 16  {'regressor__alpha': 0.01, 'regressor__fit_int...          -3.383871
# 17  {'regressor__alpha': 0.01, 'regressor__fit_int...          -2.289048
# 18  {'regressor__alpha': 0.01, 'regressor__fit_int...         -20.115273
# 19  {'regressor__alpha': 0.01, 'regressor__fit_int...         -20.115273
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0         -179.583777          -0.319888          -0.141433
# 1           -4.019951          -0.292890          -0.189152
# 2          -29.506820          -0.500955          -0.241500
# 3          -29.506820          -0.500955          -0.241500
# 4        -1908.049753          -0.383831          -0.069111
# 5         -182.671205          -0.337015          -0.120758
# 6          -92.870947          -0.175582           0.169761
# 7          -92.870947          -0.175582           0.169761
# 8        -3157.427821          -0.313584          -0.023753
# 9         -912.946407          -0.375477          -0.074015
# 10          -9.709786          -0.129191           0.153756
# 11          -9.709786          -0.129191           0.153756
# 12       -3345.562564           0.226178           0.198459
# 13       -1183.982033          -0.232106          -0.010214
# 14         -58.510446          -0.017531           0.155616
# 15         -58.510446          -0.017531           0.155616
# 16       -3365.285884           0.674331           0.480102
# 17       -1217.462716           0.406171           0.280582
# 18         -67.175406           0.414375           0.353569
# 19         -67.175406           0.414375           0.353569
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0           -0.173821         -44.581753         -10.487557
# 1           -0.150611          -1.989421          -0.560852
# 2           -0.651778         -50.009563         -20.916604
# 3           -0.651778         -50.009563         -20.916604
# 4           -0.231055        -346.340978         -84.585052
# 5           -0.173686         -59.327945         -12.901451
# 6           -0.318222        -974.997328        -336.771676
# 7           -0.318222        -974.997328        -336.771676
# 8           -0.256718        -472.914885        -129.099800
# 9           -0.208915        -228.552827         -52.535930
# 10          -0.213928       -2975.692958        -798.255887
# 11          -0.213928       -2975.692958        -798.255887
# 12          -0.260384        -483.532122        -135.387499
# 13          -0.219154        -264.248505         -65.593510
# 14          -0.208064       -3538.302258        -901.316591
# 15          -0.208064       -3538.302258        -901.316591
# 16          -0.260767        -484.493609        -136.040880
# 17          -0.220398        -267.018866         -67.167376
# 18          -0.207720       -3601.163415        -912.827736
# 19          -0.207720       -3601.163415        -912.827736
#
#     split7_test_score  split8_test_score  mean_test_score  std_test_score  \
# 0           -0.696237           0.045379       -26.292574       55.903966
# 1           -0.044678           0.008167        -0.811205        1.276278
# 2           -2.664156          -0.617514       -11.760736       16.908368
# 3           -2.664156          -0.617514       -11.760736       16.908368
# 4           -9.719309           0.146722      -261.511272      591.831530
# 5           -1.735559           0.064709       -28.721551       57.383230
# 6          -63.932026           0.120575      -164.813754      304.135740
# 7          -63.932026           0.120575      -164.813754      304.135740
# 8          -16.844554           0.185411      -420.070387      978.765263
# 9           -9.742644           0.150765      -134.175557      284.125525
# 10        -131.127193           0.418895      -437.783799      930.054250
# 11        -131.127193           0.418895      -437.783799      930.054250
# 12         -17.971347           0.152080      -442.842418     1037.104533
# 13         -12.832613           0.167675      -169.937509      367.605679
# 14        -138.604484           0.434841      -517.499424     1102.763439
# 15        -138.604484           0.434841      -517.499424     1102.763439
# 16         -18.090436          -0.173848      -445.174985     1043.237634
# 17         -13.220344           0.104202      -174.065310      377.935580
# 18        -139.129004           0.386360      -526.607139     1122.005706
# 19        -139.129004           0.386360      -526.607139     1122.005706
#
#     rank_test_score
# 0                 4
# 1                 1
# 2                 2
# 3                 2
# 4                11
# 5                 5
# 6                 7
# 7                 7
# 8                12
# 9                 6
# 10               13
# 11               13
# 12               15
# 13                9
# 14               17
# 15               17
# 16               16
# 17               10
# 18               19
# 19               19

# %%
final_model = pipeline.set_params(**grid_search.best_params_)

# %%
# prepare data
train_variables = final_train_set.drop(features_to_drop, axis=1).values
train_target = final_train_set["Transacted Price ($)"].values

# %%
final_model.fit(train_variables,train_target)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('regressor', Ridge())])

# %%
X_test = final_test_set.drop(features_to_drop, axis=1).values
y_test = final_test_set["Transacted Price ($)"].values

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# Assume X_test and y_test are your test features and target variable
# Make predictions
y_pred = pipeline.predict(X_test)
print(y_pred)
print(y_test)

# Evaluate the model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

rmse = np.sqrt(mean_squared_error(y_test.get(), y_pred.get()))
mae = mean_absolute_error(y_test.get(), y_pred.get())
mape = mean_absolute_percentage_error(y_test.get(), y_pred.get())
r2 = r2_score(y_test.get(), y_pred.get())

# Print the performance metrics
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")
print(f"MAPE: {mape}")
print(f"R^2 Score: {r2}")
# Out:
# [1730214.96131903 2014978.96115544 1202949.20010329 ... 2204466.66596672
#  2277449.50689247 2361805.1722722 ]
# [1338630.03  1823554.9   1060213.68  ... 2190680.8   1994234.588
#  2691080.43 ]
# Root Mean Squared Error: 1412734.7279772304
# Mean Absolute Error: 688636.9277099101
# MAPE: 34.36257299132565
# R^2 Score: 0.5785887914518739

# %%
from cuml.linear_model import Lasso

# %%
pipeline = Pipeline([
    ("scaler", MinMaxScaler()),
    ("regressor", Lasso())
])

# %%
param_grid = {
    'regressor__alpha': [100, 10, 1.0, 0.1, 0.01],
    'regressor__fit_intercept': [True, False],
    'regressor__normalize': [True, False]
}

# %%
# going for a 80-20 training split
tscv = TimeSeriesSplit(n_splits=9, max_train_size=4)

# %%
grid_search = GridSearchCV(pipeline, param_grid, cv=tscv, verbose=2)

# %%
features_to_drop = ["Transacted Price ($)", "Date"]
features_to_keep = [feature for feature in encoded_cudf.columns if feature not in features_to_drop]

# %%
# prepare data
lr_variables = search_set.drop(features_to_drop, axis=1).values
lr_target = search_set["Transacted Price ($)"].values

# %%
# Fit grid search (make sure to pass all columns except 'year' if it's not a feature)
grid_search.fit(lr_variables, lr_target)
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
# Out:
# Fitting 9 folds for each of 20 candidates, totalling 180 fits
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.2s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.4s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.8s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.4s
# [CV] END regressor__alpha=100, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.4s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.2s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=100, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.2s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.5s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.4s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.2s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.2s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=10, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.4s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.4s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.2s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=1.0, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.5s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.4s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.2s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.1, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=True; total time=   0.4s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=True, regressor__normalize=False; total time=   0.4s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.1s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=True; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.1s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.2s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# [CV] END regressor__alpha=0.01, regressor__fit_intercept=False, regressor__normalize=False; total time=   0.0s
# Best parameters: {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__normalize': False}
# Best score: -59.727028636084434

# %%
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
# Out:
# Best parameters: {'regressor__alpha': 100, 'regressor__fit_intercept': True, 'regressor__normalize': False}
# Best score: -59.727028636084434

# %%
results_df = pd.DataFrame(grid_search.cv_results_)
results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.090783      0.112928         0.006929        0.001587
# 1        0.212725      0.247868         0.007489        0.001552
# 2        0.031434      0.010421         0.005673        0.000417
# 3        0.044413      0.065860         0.005539        0.000721
# 4        0.084273      0.143276         0.006229        0.001337
# 5        0.074813      0.121391         0.005993        0.000762
# 6        0.031547      0.009843         0.005557        0.000222
# 7        0.044836      0.067470         0.005483        0.000637
# 8        0.073471      0.120354         0.005639        0.000988
# 9        0.077856      0.126896         0.005720        0.001023
# 10       0.029392      0.009151         0.005301        0.000335
# 11       0.049761      0.078255         0.005673        0.000829
# 12       0.086125      0.154884         0.005867        0.001320
# 13       0.073546      0.121447         0.005452        0.000787
# 14       0.029639      0.009440         0.005656        0.000908
# 15       0.044574      0.066638         0.005635        0.000395
# 16       0.074117      0.122650         0.005953        0.001251
# 17       0.078097      0.134282         0.005832        0.001047
# 18       0.029625      0.008980         0.005627        0.000416
# 19       0.045372      0.068048         0.005652        0.000901
#
#    param_regressor__alpha param_regressor__fit_intercept  \
# 0                     100                           True
# 1                     100                           True
# 2                     100                          False
# 3                     100                          False
# 4                      10                           True
# 5                      10                           True
# 6                      10                          False
# 7                      10                          False
# 8                     1.0                           True
# 9                     1.0                           True
# 10                    1.0                          False
# 11                    1.0                          False
# 12                    0.1                           True
# 13                    0.1                           True
# 14                    0.1                          False
# 15                    0.1                          False
# 16                   0.01                           True
# 17                   0.01                           True
# 18                   0.01                          False
# 19                   0.01                          False
#
#    param_regressor__normalize  \
# 0                        True
# 1                       False
# 2                        True
# 3                       False
# 4                        True
# 5                       False
# 6                        True
# 7                       False
# 8                        True
# 9                       False
# 10                       True
# 11                      False
# 12                       True
# 13                      False
# 14                       True
# 15                      False
# 16                       True
# 17                      False
# 18                       True
# 19                      False
#
#                                                params  split0_test_score  \
# 0   {'regressor__alpha': 100, 'regressor__fit_inte...        -302.730263
# 1   {'regressor__alpha': 100, 'regressor__fit_inte...        -300.825214
# 2   {'regressor__alpha': 100, 'regressor__fit_inte...         -70.827485
# 3   {'regressor__alpha': 100, 'regressor__fit_inte...       -1308.860545
# 4   {'regressor__alpha': 10, 'regressor__fit_inter...        -304.089348
# 5   {'regressor__alpha': 10, 'regressor__fit_inter...        -303.909340
# 6   {'regressor__alpha': 10, 'regressor__fit_inter...         -70.801485
# 7   {'regressor__alpha': 10, 'regressor__fit_inter...       -1311.926350
# 8   {'regressor__alpha': 1.0, 'regressor__fit_inte...        -304.225774
# 9   {'regressor__alpha': 1.0, 'regressor__fit_inte...        -304.207349
# 10  {'regressor__alpha': 1.0, 'regressor__fit_inte...         -70.798885
# 11  {'regressor__alpha': 1.0, 'regressor__fit_inte...       -1312.232414
# 12  {'regressor__alpha': 0.1, 'regressor__fit_inte...        -304.238580
# 13  {'regressor__alpha': 0.1, 'regressor__fit_inte...        -304.236854
# 14  {'regressor__alpha': 0.1, 'regressor__fit_inte...         -70.798625
# 15  {'regressor__alpha': 0.1, 'regressor__fit_inte...       -1312.262946
# 16  {'regressor__alpha': 0.01, 'regressor__fit_int...        -304.239861
# 17  {'regressor__alpha': 0.01, 'regressor__fit_int...        -304.239688
# 18  {'regressor__alpha': 0.01, 'regressor__fit_int...         -70.798599
# 19  {'regressor__alpha': 0.01, 'regressor__fit_int...       -1312.265999
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.606147          -4.300343           0.230136
# 1            0.611021          -4.492368           0.220998
# 2           -0.961922          -0.207065           0.104518
# 3           -1.865527         -53.728269          -0.274286
# 4            0.403380          -4.715281           0.232898
# 5            0.463037          -4.713655           0.232470
# 6           -1.032689          -0.207447           0.104460
# 7           -3.273245         -60.627944          -0.290369
# 8            0.362391          -4.716561           0.233516
# 9            0.369116          -4.715929           0.233475
# 10          -1.039925          -0.207485           0.104454
# 11          -3.430240         -61.360609          -0.292718
# 12           0.358139          -4.717188           0.233529
# 13           0.358819          -4.717093           0.233525
# 14          -1.040650          -0.207489           0.104453
# 15          -3.446122         -61.434116          -0.293735
# 16           0.357712          -4.717264           0.233531
# 17           0.357780          -4.717254           0.233530
# 18          -1.040723          -0.207489           0.104453
# 19          -3.447712         -61.441469          -0.293836
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0           -1.196224           0.681023           0.034657
# 1           -0.113834           0.727306           0.340837
# 2           -0.259055       -2711.628683        -327.072750
# 3            0.333956          -1.386580         -42.058571
# 4           -1.206235           0.582699          -1.558265
# 5           -1.205528           0.596577          -1.358065
# 6           -0.258938       -2712.202277        -327.246629
# 7            0.333003          -2.292112         -42.382986
# 8           -1.206616           0.574832          -1.685504
# 9           -1.206545           0.576287          -1.664323
# 10          -0.258926       -2712.259642        -327.264019
# 11           0.332908          -2.396301         -42.415834
# 12          -1.206655           0.574035          -1.698451
# 13          -1.206648           0.574181          -1.696322
# 14          -0.258925       -2712.265378        -327.265758
# 15           0.332898          -2.406856         -42.419123
# 16          -1.206658           0.573955          -1.699748
# 17          -1.206658           0.573970          -1.699535
# 18          -0.258925       -2712.265952        -327.265932
# 19           0.332897          -2.407913         -42.419452
#
#     split7_test_score  split8_test_score  mean_test_score  std_test_score  \
# 0        -1098.761944          -0.048984      -156.165088      346.322974
# 1         -233.965361          -0.046642       -59.727029      112.126418
# 2         -274.488233           0.353830      -376.109650      834.475349
# 3        -6994.171415          -0.126512      -933.570861     2180.525421
# 4        -1101.392516          -0.051821      -156.866054      347.067053
# 5        -1101.227007          -0.074343      -156.799539      347.021148
# 6         -274.610032           0.353866      -376.211241      834.648449
# 7        -6999.601965          -0.127473      -935.576605     2181.827328
# 8        -1101.495973          -0.020712      -156.908933      347.097495
# 9        -1101.479421          -0.056187      -156.905653      347.091336
# 10        -274.622214           0.353869      -376.221419      834.665753
# 11       -7000.145136          -0.127576      -935.785324     2181.954277
# 12       -1101.506319          -0.017721      -156.913246      347.100448
# 13       -1101.504664          -0.053495      -156.916506      347.098222
# 14        -274.623432           0.353870      -376.222437      834.667483
# 15       -7000.199454          -0.127586      -935.806338     2181.966909
# 16       -1101.507354          -0.017558      -156.913694      347.100736
# 17       -1101.507188          -0.053089      -156.917570      347.098908
# 18        -274.623554           0.353870      -376.222539      834.667656
# 19       -7000.204886          -0.127587      -935.808440     2181.968172
#
#     rank_test_score
# 0                 2
# 1                 1
# 2                11
# 3                16
# 4                 4
# 5                 3
# 6                12
# 7                17
# 8                 6
# 9                 5
# 10               13
# 11               18
# 12                7
# 13                9
# 14               14
# 15               19
# 16                8
# 17               10
# 18               15
# 19               20

# %%
final_model = pipeline.set_params(**grid_search.best_params_)

# %%
# prepare data
train_variables = final_train_set.drop(features_to_drop, axis=1).values
train_target = final_train_set["Transacted Price ($)"].values

# %%
final_model.fit(train_variables,train_target)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('regressor', Lasso())])

# %%
X_test = final_test_set.drop(features_to_drop, axis=1).values
y_test = final_test_set["Transacted Price ($)"].values

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# Assume X_test and y_test are your test features and target variable
# Make predictions
y_pred = pipeline.predict(X_test)
print(y_pred)
print(y_test)

# Evaluate the model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

rmse = np.sqrt(mean_squared_error(y_test.get(), y_pred.get()))
mae = mean_absolute_error(y_test.get(), y_pred.get())
mape = mean_absolute_percentage_error(y_test.get(), y_pred.get())
r2 = r2_score(y_test.get(), y_pred.get())

# Print the performance metrics
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")
print(f"MAPE: {mape}")
print(f"R^2 Score: {r2}")
# Out:
# [1624828.74535507 1978224.87162138  985491.24709066 ... 2442929.7075525
#  2246774.08005425 2600668.08192821]
# [1338630.03  1823554.9   1060213.68  ... 2190680.8   1994234.588
#  2691080.43 ]
# Root Mean Squared Error: 1024562.206042669
# Mean Absolute Error: 515211.5885262565
# MAPE: 24.737137966073284
# R^2 Score: 0.778353180630318

# %%
df = pd.DataFrame.from_dict(grid_search.cv_results_)
df
