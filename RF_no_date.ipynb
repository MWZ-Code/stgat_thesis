# %% [markdown]
# <a href="https://colab.research.google.com/github/Mak-Wei-Zheng/stgat_thesis/blob/main/RF_no_date.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Apr 23 12:37:09 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   37C    P8              11W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# This get the RAPIDS-Colab install files and test check your GPU.  Run this and the next cell only.
# Please read the output of this cell.  If your Colab Instance is not RAPIDS compatible, it will warn you and give you remediation steps.
# !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
# !python rapidsai-csp-utils/colab/pip-install.py

# %%
# prompt: import libraries for linear regression using cuml
import numpy as np
import cupy as cp

import pandas as pd
import cudf as cd

import numba
import numba.cuda

from cuml import Ridge as cumlRidge

from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
raw_data = pd.read_csv("/content/drive/MyDrive/raw_all_data.csv")

# %%
raw_data.shape
# Out:
# (162575, 24)

# %%
raw_data.dtypes
# Out:
# Date                                               object
# SORA Index                                        float64
# Compound SORA - 1 month                           float64
# Compound SORA - 3 month                           float64
# Quarterly Composite Leading Index                 float64
# Services Inflation Measure (Index)                float64
# Retail & Other Goods Inflation Measure (Index)    float64
# Electricity & Gas Inflation Measure (Index)       float64
# Week                                              float64
# Year                                              float64
# Transacted Price ($)                              float64
# Area (SQFT)                                       float64
# Type of Sale                                       object
# Type of Area                                       object
# Property Type                                      object
# Postal District                                   float64
# Planning Region                                    object
# Planning Area                                      object
# Sale Date                                          object
# latitude                                          float64
# longitude                                         float64
# is_freehold                                        object
# tenure_remaining                                  float64
# region classification                              object
# dtype: object

# %%
raw_data["Transacted Price ($)"].head()
# Out:
# 0    2160605.75
# 1    1186731.00
# 2    1979959.12
# 3    2820688.12
# 4    1299973.08
# Name: Transacted Price ($), dtype: float64

# %% [markdown]
# ### This portion of the code is for grid search over RF variables with my custom train-val-test split

# %%
# trim data
columns_to_drop = ["SORA Index", "Compound SORA - 1 month", "Sale Date", "latitude", "longitude"]
rf_total_df = raw_data.drop(columns_to_drop, axis=1)
rf_total_df.head()
# Out:
#          Date  Compound SORA - 3 month  Quarterly Composite Leading Index  \
# 0  2014-02-28                   0.0444                               99.8
# 1  2014-02-28                   0.0444                               99.8
# 2  2014-02-28                   0.0444                               99.8
# 3  2014-02-28                   0.0444                               99.8
# 4  2014-02-28                   0.0444                               99.8
#
#    Services Inflation Measure (Index)  \
# 0                              93.063
# 1                              93.063
# 2                              93.063
# 3                              93.063
# 4                              93.063
#
#    Retail & Other Goods Inflation Measure (Index)  \
# 0                                          97.714
# 1                                          97.714
# 2                                          97.714
# 3                                          97.714
# 4                                          97.714
#
#    Electricity & Gas Inflation Measure (Index)  Week    Year  \
# 0                                      117.098   9.0  2014.0
# 1                                      117.098   9.0  2014.0
# 2                                      117.098   9.0  2014.0
# 3                                      117.098   9.0  2014.0
# 4                                      117.098   9.0  2014.0
#
#    Transacted Price ($)  Area (SQFT) Type of Sale Type of Area Property Type  \
# 0            2160605.75      2335.79       Resale       Strata   Condominium
# 1            1186731.00       968.76     New Sale       Strata   Condominium
# 2            1979959.12      1065.64       Resale       Strata   Condominium
# 3            2820688.12      1636.13       Resale       Strata   Condominium
# 4            1299973.08       871.88     Sub Sale       Strata   Condominium
#
#    Postal District    Planning Region Planning Area is_freehold  \
# 0             11.0     Central Region   Bukit Timah        True
# 1             13.0     Central Region     Toa Payoh       False
# 2             10.0     Central Region       Tanglin        True
# 3              4.0     Central Region   Bukit Merah       False
# 4             20.0  North East Region    Ang Mo Kio       False
#
#    tenure_remaining region classification
# 0               NaN                   CCR
# 1           35452.0                   RCR
# 2               NaN                   CCR
# 3           30825.0                   RCR
# 4           33864.0                   OCR

# %%
# categorical encoding
one_hot_cols = ["region classification", "Type of Area", "Type of Sale"]
binary_cols = ["Planning Area", "Postal District", "Property Type", "Planning Region"]

# %%
# !pip install category-encoders
# Out:
# Collecting category-encoders
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (1.11.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (0.14.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (2.0.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category-encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category-encoders) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category-encoders) (2024.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category-encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category-encoders) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category-encoders) (3.4.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category-encoders) (24.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.6.3

# %%
import category_encoders as ce

# Create a binary encoder
encoder = ce.BinaryEncoder(cols=binary_cols)

# Fit and transform to generate binary encoded DataFrame
binary_encoded_df = encoder.fit_transform(rf_total_df)

# one-hot encode
total_encoded_df = pd.get_dummies(binary_encoded_df, columns=one_hot_cols, prefix='cat')

# %%
total_encoded_df.dtypes
# Out:
# Date                                               object
# Compound SORA - 3 month                           float64
# Quarterly Composite Leading Index                 float64
# Services Inflation Measure (Index)                float64
# Retail & Other Goods Inflation Measure (Index)    float64
# Electricity & Gas Inflation Measure (Index)       float64
# Week                                              float64
# Year                                              float64
# Transacted Price ($)                              float64
# Area (SQFT)                                       float64
# Property Type_0                                     int64
# Property Type_1                                     int64
# Property Type_2                                     int64
# Postal District_0                                   int64
# Postal District_1                                   int64
# Postal District_2                                   int64
# Postal District_3                                   int64
# Postal District_4                                   int64
# Planning Region_0                                   int64
# Planning Region_1                                   int64
# Planning Region_2                                   int64
# Planning Area_0                                     int64
# Planning Area_1                                     int64
# Planning Area_2                                     int64
# Planning Area_3                                     int64
# Planning Area_4                                     int64
# Planning Area_5                                     int64
# is_freehold                                        object
# tenure_remaining                                  float64
# cat_CCR                                              bool
# cat_OCR                                              bool
# cat_RCR                                              bool
# cat_Land                                             bool
# cat_Strata                                           bool
# cat_New Sale                                         bool
# cat_Resale                                           bool
# cat_Sub Sale                                         bool
# dtype: object

# %%
# convert date to datetime object
from datetime import datetime

total_encoded_df["Date"] = total_encoded_df["Date"].apply(lambda x: datetime.strptime(x, "%Y-%m-%d"))

# %%
total_encoded_df["Transacted Price ($)"] = rf_total_df["Transacted Price ($)"]

# %%
total_encoded_df["tenure_remaining"].fillna(0, inplace=True)
total_encoded_df.dropna(axis=0, inplace=True)
total_encoded_df.head()
# Out:
#         Date  Compound SORA - 3 month  Quarterly Composite Leading Index  \
# 0 2014-02-28                   0.0444                               99.8
# 1 2014-02-28                   0.0444                               99.8
# 2 2014-02-28                   0.0444                               99.8
# 3 2014-02-28                   0.0444                               99.8
# 4 2014-02-28                   0.0444                               99.8
#
#    Services Inflation Measure (Index)  \
# 0                              93.063
# 1                              93.063
# 2                              93.063
# 3                              93.063
# 4                              93.063
#
#    Retail & Other Goods Inflation Measure (Index)  \
# 0                                          97.714
# 1                                          97.714
# 2                                          97.714
# 3                                          97.714
# 4                                          97.714
#
#    Electricity & Gas Inflation Measure (Index)  Week    Year  \
# 0                                      117.098   9.0  2014.0
# 1                                      117.098   9.0  2014.0
# 2                                      117.098   9.0  2014.0
# 3                                      117.098   9.0  2014.0
# 4                                      117.098   9.0  2014.0
#
#    Transacted Price ($)  Area (SQFT)  ...  is_freehold  tenure_remaining  \
# 0            2160605.75      2335.79  ...         True               0.0
# 1            1186731.00       968.76  ...        False           35452.0
# 2            1979959.12      1065.64  ...         True               0.0
# 3            2820688.12      1636.13  ...        False           30825.0
# 4            1299973.08       871.88  ...        False           33864.0
#
#    cat_CCR  cat_OCR  cat_RCR  cat_Land  cat_Strata  cat_New Sale  cat_Resale  \
# 0     True    False    False     False        True         False        True
# 1    False    False     True     False        True          True       False
# 2     True    False    False     False        True         False        True
# 3    False    False     True     False        True         False        True
# 4    False     True    False     False        True         False       False
#
#    cat_Sub Sale
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#
# [5 rows x 37 columns]

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.2

# %%
encoded_cudf = cd.from_pandas(total_encoded_df)

# %%
encoded_cudf.head()
# Out:
#         Date  Compound SORA - 3 month  Quarterly Composite Leading Index  \
# 0 2014-02-28                   0.0444                               99.8
# 1 2014-02-28                   0.0444                               99.8
# 2 2014-02-28                   0.0444                               99.8
# 3 2014-02-28                   0.0444                               99.8
# 4 2014-02-28                   0.0444                               99.8
#
#    Services Inflation Measure (Index)  \
# 0                              93.063
# 1                              93.063
# 2                              93.063
# 3                              93.063
# 4                              93.063
#
#    Retail & Other Goods Inflation Measure (Index)  \
# 0                                          97.714
# 1                                          97.714
# 2                                          97.714
# 3                                          97.714
# 4                                          97.714
#
#    Electricity & Gas Inflation Measure (Index)  Week    Year  \
# 0                                      117.098   9.0  2014.0
# 1                                      117.098   9.0  2014.0
# 2                                      117.098   9.0  2014.0
# 3                                      117.098   9.0  2014.0
# 4                                      117.098   9.0  2014.0
#
#    Transacted Price ($)  Area (SQFT)  ...  is_freehold  tenure_remaining  \
# 0            2160605.75      2335.79  ...         True               0.0
# 1            1186731.00       968.76  ...        False           35452.0
# 2            1979959.12      1065.64  ...         True               0.0
# 3            2820688.12      1636.13  ...        False           30825.0
# 4            1299973.08       871.88  ...        False           33864.0
#
#    cat_CCR  cat_OCR  cat_RCR  cat_Land  cat_Strata  cat_New Sale  cat_Resale  \
# 0     True    False    False     False        True         False        True
# 1    False    False     True     False        True          True       False
# 2     True    False    False     False        True         False        True
# 3    False    False     True     False        True         False        True
# 4    False     True    False     False        True         False       False
#
#    cat_Sub Sale
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#
# [5 rows x 37 columns]

# %%
# convert week and year to int
encoded_cudf["Year"] = encoded_cudf["Year"].astype(int)
encoded_cudf["Week"] = encoded_cudf["Week"].astype(int)

# %%
def filter_years(df, start_year, end_year=None):
    if end_year is None:
        end_year = start_year
    return df[(df['Year'] >= start_year) & (df['Year'] <= end_year)]

def get_latest_year_indices(df):
    max_year = df['Year'].max()
    return df[df['Year'] == max_year].index

search_set = filter_years(encoded_cudf, 2014, 2022) # representing ~9 years of data

final_train_set = filter_years(encoded_cudf, 2019, 2022)
final_test_set = filter_years(encoded_cudf, 2023)

print(search_set.shape, final_train_set.shape, final_test_set.shape)
# Out:
# (146243, 37) (76887, 37) (16229, 37)

# %%
# import dependencies
from cuml.ensemble import RandomForestRegressor
from cuml.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.pipeline import Pipeline
import numpy as np

# %%
pipeline = Pipeline([
    ("scaler", MinMaxScaler()),
    ("regressor", RandomForestRegressor())
])

# %%
param_grid = {
    'regressor__n_estimators': [20, 50, 100, 200],
    'regressor__max_depth': [3, 5, 10, 20],
    'regressor__bootstrap': [True, False],
    'regressor__split_criterion': [2,3,4,5]
}

# %%
# going for a 80-20 training split
tscv = TimeSeriesSplit(n_splits=9, max_train_size=4)

# %%
grid_search = GridSearchCV(pipeline, param_grid, cv=tscv, verbose=2)

# %%
features_to_drop = ["Year", "Week", "Transacted Price ($)", "Date"]
features_to_keep = [feature for feature in encoded_cudf.columns if feature not in features_to_drop]

# %%
# prepare data
rf_variables = search_set.drop(features_to_drop, axis=1).values
rf_target = search_set["Transacted Price ($)"].values

# %%
# Fit grid search (make sure to pass all columns except 'year' if it's not a feature)
grid_search.fit(rf_variables, rf_target)
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# %%
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
# Out:
# Best parameters: {'regressor__bootstrap': True, 'regressor__max_depth': 3, 'regressor__n_estimators': 100, 'regressor__split_criterion': 4}
# Best score: -0.07636038680270536

# %%
results_df = pd.DataFrame(grid_search.cv_results_)
results_df

# %%
final_model = pipeline.set_params(**grid_search.best_params_)

# %%
# prepare data
train_variables = final_train_set.drop(features_to_drop, axis=1).values
train_target = final_train_set["Transacted Price ($)"].values

# %%
final_model.fit(train_variables,train_target)
# Out:
# /usr/local/lib/python3.10/dist-packages/cuml/internals/api_decorators.py:188: UserWarning: To use pickling first train using float32 data to fit the estimator
#   ret = func(*args, **kwargs)
# Pipeline(steps=[('regressor', RandomForestRegressor())])

# %%
X_test = final_test_set.drop(features_to_drop, axis=1).values
y_test = final_test_set["Transacted Price ($)"].values

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# Assume X_test and y_test are your test features and target variable
# Make predictions
y_pred = pipeline.predict(X_test)
print(y_pred)
print(y_test)

# Evaluate the model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

rmse = np.sqrt(mean_squared_error(y_test.get(), y_pred.get()))
mae = mean_absolute_error(y_test.get(), y_pred.get())
mape = mean_absolute_percentage_error(y_test.get(), y_pred.get())
r2 = r2_score(y_test.get(), y_pred.get())

# Print the performance metrics
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")
print(f"MAPE: {mape}")
print(f"R^2 Score: {r2}")
# Out:
# [1434124.04815845 1429295.7874423  1429295.7874423  ... 1429295.7874423
#  1429295.7874423  1429295.7874423 ]
# [1338630.03  1823554.9   1060213.68  ... 2190680.8   1994234.588
#  2691080.43 ]
# Root Mean Squared Error: 1280325.3374180172
# Mean Absolute Error: 601259.2494045702
# MAPE: 23.761981238757173
# R^2 Score: 0.6538809359207225

# %% [markdown]
# #### Exploring using log(price) instead

# %%
total_encoded_log_df = total_encoded_df
total_encoded_log_df["Transacted Price ($)"] = total_encoded_log_df["Transacted Price ($)"].apply(np.log)
encoded_log_cudf = cd.from_pandas(total_encoded_log_df)

# %%
search_log_set = filter_years(encoded_log_cudf, 2014, 2022) # representing ~9 years of data

final_log_train_set = filter_years(encoded_log_cudf, 2019, 2022)
final_log_test_set = filter_years(encoded_log_cudf, 2023)

print(search_set.shape, final_train_set.shape, final_test_set.shape)
# Out:
# (146243, 37) (76887, 37) (16229, 37)

# %%
pipeline = Pipeline([
    ("scaler", MinMaxScaler())
    ("regressor", RandomForestRegressor())
])
# Out:
# <>:2: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# <>:2: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# <ipython-input-205-6438575b9e6c>:2: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
#   ("scaler", MinMaxScaler())
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-205-6438575b9e6c> in <cell line: 1>()
#       1 pipeline = Pipeline([
# ----> 2     ("scaler", MinMaxScaler())
#       3     ("regressor", RandomForestRegressor())
#       4 ])
#
# TypeError: 'tuple' object is not callable

# %%
log_grid_search = GridSearchCV(pipeline, param_grid, cv=tscv, verbose=2)

# %%
# prepare data
rf_log_variables = search_log_set.drop(features_to_drop, axis=1).values
rf_log_target = search_log_set["Transacted Price ($)"].values

# %%
# Fit grid search (make sure to pass all columns except 'year' if it's not a feature)
log_grid_search.fit(rf_log_variables, rf_log_target)
print("Best parameters:", log_grid_search.best_params_)
print("Best score:", log_grid_search.best_score_)
# Out:
# Fitting 9 folds for each of 128 candidates, totalling 1152 fits
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# /usr/local/lib/python3.10/dist-packages/cuml/internals/api_decorators.py:188: UserWarning: The number of bins, `n_bins` is greater than the number of samples used for training. Changing `n_bins` to number of training samples.
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/cuml/internals/api_decorators.py:188: UserWarning: To use pickling first train using float32 data to fit the estimator
#   ret = func(*args, **kwargs)
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.2s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.2s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.2s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.2s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.2s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.2s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.2s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.2s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=3, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=50, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=5, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=20, regressor__split_criterion=5; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=2; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# [CV] END regressor__bootstrap=True, regressor__max_depth=10, regressor__n_estimators=50, regressor__split_criterion=4; total time=   0.0s
# ...
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=100, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.2s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.2s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.2s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.2s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=2; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=3; total time=   0.0s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=4; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# [CV] END regressor__bootstrap=False, regressor__max_depth=20, regressor__n_estimators=200, regressor__split_criterion=5; total time=   0.1s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 288 fits failed out of a total of 1152.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 288 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.10/dist-packages/nvtx/nvtx.py", line 116, in inner
#     result = func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/cuml/internals/api_decorators.py", line 188, in wrapper
#     ret = func(*args, **kwargs)
#   File "randomforestregressor.pyx", line 438, in cuml.ensemble.randomforestregressor.RandomForestRegressor.fit
# RuntimeError: exception occurred! file=/__w/cuml/cuml/cpp/src/decisiontree/decisiontree.cu line=38: MAE not supported.
# Obtained 63 stack frames
# #1 in /usr/local/lib/python3.10/dist-packages/cuml/internals/../libcuml++.so(+0x1a7032c) [0x7cffa7bf332c]
# #2 in /usr/local/lib/python3.10/dist-packages/cuml/internals/../libcuml++.so: ML::DT::set_tree_params(ML::DT::DecisionTreeParams&, int, int, float, int, int, int, float, ML::CRITERION, int) +0x61 [0x7cffa83ce5e1]
# #3 in /usr/local/lib/python3.10/dist-packages/cuml/internals/../libcuml++.so: ML::set_rf_params(int, int, float, int, int, int, float, bool, int, float, unsigned long, ML::CRITERION, int, int) +0x45 [0x7cffa8c1c365]
# #4 in /usr/local/lib/python3.10/dist-packages/cuml/ensemble/randomforestregressor.cpython-310-x86_64-linux-gnu.so(+0x3bd26) [0x7d003390fd26]
# #5 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x2a27 [0x5bfcc70be5d7]
# #6 in /usr/bin/python3: _PyFunction_Vectorcall +0x7c [0x5bfcc70d39fc]
# #7 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x2a27 [0x5bfcc70be5d7]
# #8 in /usr/bin/python3(+0x16893e) [0x5bfcc70e193e]
# #9 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x2a27 [0x5bfcc70be5d7]
# #10 in /usr/bin/python3(+0x16893e) [0x5bfcc70e193e]
# #11 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x2a27 [0x5bfcc70be5d7]
# #12 in /usr/bin/python3: _PyFunction_Vectorcall +0x7c [0x5bfcc70d39fc]
# #13 in /usr/bin/python3: PyObject_Call +0x122 [0x5bfcc70e2492]
# #14 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x2a27 [0x5bfcc70be5d7]
# #15 in /usr/bin/python3: _PyFunction_Vectorcall +0x7c [0x5bfcc70d39fc]
# #16 in /usr/bin/python3: _PyObject_FastCallDictTstate +0x16d [0x5bfcc70c8cbd]
# #17 in /usr/bin/python3: _PyObject_Call_Prepend +0x5c [0x5bfcc70de86c]
# #18 in /usr/bin/python3(+0x280700) [0x5bfcc71f9700]
# #19 in /usr/bin/python3: PyObject_Call +0xbb [0x5bfcc70e242b]
# #20 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x2a27 [0x5bfcc70be5d7]
# #21 in /usr/bin/python3(+0x177cc2) [0x5bfcc70f0cc2]
# #22 in /usr/bin/python3(+0x17dd24) [0x5bfcc70f6d24]
# #23 in /usr/bin/python3(+0x1d2176) [0x5bfcc714b176]
# #24 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x6bd [0x5bfcc70bc26d]
# #25 in /usr/bin/python3(+0x1687f1) [0x5bfcc70e17f1]
# #26 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x614a [0x5bfcc70c1cfa]
# #27 in /usr/bin/python3: _PyObject_FastCallDictTstate +0xc4 [0x5bfcc70c8c14]
# #28 in /usr/bin/python3: _PyObject_Call_Prepend +0x5c [0x5bfcc70de86c]
# #29 in /usr/bin/python3(+0x280700) [0x5bfcc71f9700]
# #30 in /usr/bin/python3: _PyObject_MakeTpCall +0x25b [0x5bfcc70c9a7b]
# #31 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x64e6 [0x5bfcc70c2096]
# #32 in /usr/bin/python3: _PyFunction_Vectorcall +0x7c [0x5bfcc70d39fc]
# #33 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x6bd [0x5bfcc70bc26d]
# #34 in /usr/bin/python3: _PyFunction_Vectorcall +0x7c [0x5bfcc70d39fc]
# #35 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x8ac [0x5bfcc70bc45c]
# #36 in /usr/bin/python3: _PyFunction_Vectorcall +0x7c [0x5bfcc70d39fc]
# #37 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x8ac [0x5bfcc70bc45c]
# #38 in /usr/bin/python3(+0x13f9c6) [0x5bfcc70b89c6]
# #39 in /usr/bin/python3: PyEval_EvalCode +0x86 [0x5bfcc71ae256]
# #40 in /usr/bin/python3(+0x23ae2d) [0x5bfcc71b3e2d]
# #41 in /usr/bin/python3(+0x15ac59) [0x5bfcc70d3c59]
# #42 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x6bd [0x5bfcc70bc26d]
# #43 in /usr/bin/python3(+0x177ff0) [0x5bfcc70f0ff0]
# #44 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x2568 [0x5bfcc70be118]
# #45 in /usr/bin/python3(+0x177ff0) [0x5bfcc70f0ff0]
# #46 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x2568 [0x5bfcc70be118]
# #47 in /usr/bin/python3(+0x177ff0) [0x5bfcc70f0ff0]
# #48 in /usr/bin/python3(+0x2557af) [0x5bfcc71ce7af]
# #49 in /usr/bin/python3(+0x1662ca) [0x5bfcc70df2ca]
# #50 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x8ac [0x5bfcc70bc45c]
# #51 in /usr/bin/python3: _PyFunction_Vectorcall +0x7c [0x5bfcc70d39fc]
# #52 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x6bd [0x5bfcc70bc26d]
# #53 in /usr/bin/python3: _PyFunction_Vectorcall +0x7c [0x5bfcc70d39fc]
# #54 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x8ac [0x5bfcc70bc45c]
# #55 in /usr/bin/python3(+0x1687f1) [0x5bfcc70e17f1]
# #56 in /usr/bin/python3: PyObject_Call +0x122 [0x5bfcc70e2492]
# #57 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x2a27 [0x5bfcc70be5d7]
# #58 in /usr/bin/python3(+0x1687f1) [0x5bfcc70e17f1]
# #59 in /usr/bin/python3: _PyEval_EvalFrameDefault +0x198c [0x5bfcc70bd53c]
# #60 in /usr/bin/python3(+0x200175) [0x5bfcc7179175]
# #61 in /usr/bin/python3(+0x15ac59) [0x5bfcc70d3c59]
# #62 in /usr/bin/python3(+0x236bc5) [0x5bfcc71afbc5]
# #63 in /usr/bin/python3(+0x2b2572) [0x5bfcc722b572]
#
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [-0.41456623         nan -0.47293164 -0.48046132 -0.36901856         nan
#  -0.40174867 -0.40781651 -0.33873502         nan -0.3754908  -0.36891612
#  -0.35150365         nan -0.37541668 -0.38952762 -0.41456623         nan
#  -0.47293164 -0.48046132 -0.36901856         nan -0.40174867 -0.40781651
#  -0.33873502         nan -0.3754908  -0.36891612 -0.35150365         nan
#  -0.37541668 -0.38952762 -0.41456623         nan -0.47293164 -0.48046132
#  -0.36901856         nan -0.40174867 -0.40781651 -0.33873502         nan
#  -0.3754908  -0.36891612 -0.35150365         nan -0.37541668 -0.38952762
#  -0.41456623         nan -0.47293164 -0.48046132 -0.36901856         nan
#  -0.40174867 -0.40781651 -0.33873502         nan -0.3754908  -0.36891612
#  -0.35150365         nan -0.37541668 -0.38952762 -0.77174661         nan
#  -0.79865835 -0.79865835 -0.77174661         nan -0.79865835 -0.79865835
#  -0.77174661         nan -0.79865835 -0.79865835 -0.77174661         nan
#  -0.79865835 -0.79865835 -0.77174661         nan -0.79865835 -0.79865835
#  -0.77174661         nan -0.79865835 -0.79865835 -0.77174661         nan
#  -0.79865835 -0.79865835 -0.77174661         nan -0.79865835 -0.79865835
#  -0.77174661         nan -0.79865835 -0.79865835 -0.77174661         nan
#  -0.79865835 -0.79865835 -0.77174661         nan -0.79865835 -0.79865835
#  -0.77174661         nan -0.79865835 -0.79865835 -0.77174661         nan
#  -0.79865835 -0.79865835 -0.77174661         nan -0.79865835 -0.79865835
#  -0.77174661         nan -0.79865835 -0.79865835 -0.77174661         nan
#  -0.79865835 -0.79865835]
#   warnings.warn(
# Best parameters: {'regressor__bootstrap': True, 'regressor__max_depth': 3, 'regressor__n_estimators': 100, 'regressor__split_criterion': 2}
# Best score: -0.3387350150040047

# %%
print("Best parameters:", log_grid_search.best_params_)
print("Best score:", log_grid_search.best_score_)
# Out:
# Best parameters: {'regressor__bootstrap': True, 'regressor__max_depth': 3, 'regressor__n_estimators': 100, 'regressor__split_criterion': 2}
# Best score: -0.3387350150040047

# %%
final_log_model = pipeline.set_params(**log_grid_search.best_params_)

# %%
# prepare data
train_log_variables = final_log_train_set.drop(features_to_drop, axis=1).values
train_log_target = final_log_train_set["Transacted Price ($)"].values

# %%
final_log_model.fit(train_log_variables,train_log_target)
# Out:
# Pipeline(steps=[('regressor', RandomForestRegressor())])

# %%
final_log_test_set.head()
# Out:
#              Date  Compound SORA - 3 month  Quarterly Composite Leading Index  \
# 146346 2023-01-02                   3.0966                              110.5
# 146347 2023-01-02                   3.0966                              110.5
# 146348 2023-01-03                   3.0294                              110.5
# 146349 2023-01-03                   3.0294                              110.5
# 146350 2023-01-03                   3.0294                              110.5
#
#         Services Inflation Measure (Index)  \
# 146346                             105.128
# 146347                             105.128
# 146348                             105.128
# 146349                             105.128
# 146350                             105.128
#
#         Retail & Other Goods Inflation Measure (Index)  \
# 146346                                         100.221
# 146347                                         100.221
# 146348                                         100.221
# 146349                                         100.221
# 146350                                         100.221
#
#         Electricity & Gas Inflation Measure (Index)  Week    Year  \
# 146346                                       115.38   1.0  2023.0
# 146347                                       115.38   1.0  2023.0
# 146348                                       115.38   1.0  2023.0
# 146349                                       115.38   1.0  2023.0
# 146350                                       115.38   1.0  2023.0
#
#         Transacted Price ($)  Area (SQFT)  ...  is_freehold  tenure_remaining  \
# 146346             14.107157      1054.87  ...        False           35449.0
# 146347             14.416298       882.65  ...         True               0.0
# 146348             13.873981       775.01  ...        False           31817.0
# 146349             14.450983       678.13  ...         True               0.0
# 146350             14.371982      1334.74  ...        False           32720.0
#
#         cat_CCR  cat_OCR  cat_RCR  cat_Land  cat_Strata  cat_New Sale  \
# 146346    False     True    False     False        True          True
# 146347    False     True    False     False        True          True
# 146348    False     True    False     False        True         False
# 146349    False    False     True     False        True          True
# 146350    False     True    False     False        True         False
#
#         cat_Resale  cat_Sub Sale
# 146346       False         False
# 146347       False         False
# 146348        True         False
# 146349       False         False
# 146350        True         False
#
# [5 rows x 37 columns]

# %%
X_test = final_log_test_set.drop(features_to_drop, axis=1).values
y_test = final_test_set["Transacted Price ($)"].values

# %%
# Assume X_test and y_test are your test features and target variable
# Make predictions
y_log_pred = pipeline.predict(X_test)
y_pred = cp.exp(y_log_pred)
print(y_pred)
print(y_test)

# Evaluate the model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

rmse = np.sqrt(mean_squared_error(y_test.get(), y_pred.get()))
mae = mean_absolute_error(y_test.get(), y_pred.get())
mape = mean_absolute_percentage_error(y_test.get(), y_pred.get())
r2 = r2_score(y_test.get(), y_pred.get())

# Print the performance metrics
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")
print(f"MAPE: {mape}")
print(f"R^2 Score: {r2}")
# Out:
# [1205195.77657142 1205195.77657142 1205195.77657142 ... 1205195.77657142
#  1760454.30947889 1760454.30947889]
# [1338630.03  1823554.9   1060213.68  ... 2190680.8   1994234.588
#  2691080.43 ]
# Root Mean Squared Error: 1420698.4199479262
# Mean Absolute Error: 623067.5841317202
# MAPE: 22.879344720112485
# R^2 Score: 0.5738243470411044
